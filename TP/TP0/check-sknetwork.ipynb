# %% [markdown]
# # SD212: Graph mining

# %% [markdown]
# # Check scikit-network

# %% [markdown]
# This notebook aims at checking that you can work with the [scikit-network](https://scikit-network.readthedocs.io/en/latest/index.html) package.

# %% [markdown]
# ## Installation

# %% [markdown]
# If you don't have scikit-network installed, run the following cell and restart the kernel.

# %%
# !pip install scikit-network
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-network
#   Using cached scikit-network-0.30.0.tar.gz (1.5 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.22.4 in c:\users\ttper\appdata\roaming\python\python311\site-packages (from scikit-network) (1.23.5)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\ttper\appdata\roaming\python\python311\site-packages (from scikit-network) (1.10.0)
# Building wheels for collected packages: scikit-network
#   Building wheel for scikit-network (setup.py): started
#   Building wheel for scikit-network (setup.py): finished with status 'error'
#   Running setup.py clean for scikit-network
# Failed to build scikit-network
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [262 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-311
#       creating build\lib.win-amd64-cpython-311\sknetwork
#       copying sknetwork\sknetwork.py -> build\lib.win-amd64-cpython-311\sknetwork
#       copying sknetwork\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork
#       creating build\lib.win-amd64-cpython-311\sknetwork\classification
#       copying sknetwork\classification\base.py -> build\lib.win-amd64-cpython-311\sknetwork\classification
#       copying sknetwork\classification\base_rank.py -> build\lib.win-amd64-cpython-311\sknetwork\classification
#       copying sknetwork\classification\diffusion.py -> build\lib.win-amd64-cpython-311\sknetwork\classification
#       copying sknetwork\classification\knn.py -> build\lib.win-amd64-cpython-311\sknetwork\classification
#       copying sknetwork\classification\metrics.py -> build\lib.win-amd64-cpython-311\sknetwork\classification
#       copying sknetwork\classification\pagerank.py -> build\lib.win-amd64-cpython-311\sknetwork\classification
#       copying sknetwork\classification\propagation.py -> build\lib.win-amd64-cpython-311\sknetwork\classification
#       copying sknetwork\classification\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\classification
#       creating build\lib.win-amd64-cpython-311\sknetwork\clustering
#       copying sknetwork\clustering\base.py -> build\lib.win-amd64-cpython-311\sknetwork\clustering
#       copying sknetwork\clustering\louvain.py -> build\lib.win-amd64-cpython-311\sknetwork\clustering
#       copying sknetwork\clustering\metrics.py -> build\lib.win-amd64-cpython-311\sknetwork\clustering
#       copying sknetwork\clustering\postprocess.py -> build\lib.win-amd64-cpython-311\sknetwork\clustering
#       copying sknetwork\clustering\propagation_clustering.py -> build\lib.win-amd64-cpython-311\sknetwork\clustering
#       copying sknetwork\clustering\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\clustering
#       creating build\lib.win-amd64-cpython-311\sknetwork\data
#       copying sknetwork\data\load.py -> build\lib.win-amd64-cpython-311\sknetwork\data
#       copying sknetwork\data\models.py -> build\lib.win-amd64-cpython-311\sknetwork\data
#       copying sknetwork\data\parse.py -> build\lib.win-amd64-cpython-311\sknetwork\data
#       copying sknetwork\data\test_graphs.py -> build\lib.win-amd64-cpython-311\sknetwork\data
#       copying sknetwork\data\toy_graphs.py -> build\lib.win-amd64-cpython-311\sknetwork\data
#       copying sknetwork\data\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\data
#       creating build\lib.win-amd64-cpython-311\sknetwork\embedding
#       copying sknetwork\embedding\base.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding
#       copying sknetwork\embedding\force_atlas.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding
#       copying sknetwork\embedding\louvain_embedding.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding
#       copying sknetwork\embedding\louvain_hierarchy.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding
#       copying sknetwork\embedding\random_projection.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding
#       copying sknetwork\embedding\spectral.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding
#       copying sknetwork\embedding\spring.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding
#       copying sknetwork\embedding\svd.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding
#       copying sknetwork\embedding\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding
#       creating build\lib.win-amd64-cpython-311\sknetwork\gnn
#       copying sknetwork\gnn\activation.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn
#       copying sknetwork\gnn\base.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn
#       copying sknetwork\gnn\base_activation.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn
#       copying sknetwork\gnn\base_layer.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn
#       copying sknetwork\gnn\gnn_classifier.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn
#       copying sknetwork\gnn\layer.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn
#       copying sknetwork\gnn\loss.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn
#       copying sknetwork\gnn\neighbor_sampler.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn
#       copying sknetwork\gnn\optimizer.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn
#       copying sknetwork\gnn\utils.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn
#       copying sknetwork\gnn\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn
#       creating build\lib.win-amd64-cpython-311\sknetwork\hierarchy
#       copying sknetwork\hierarchy\base.py -> build\lib.win-amd64-cpython-311\sknetwork\hierarchy
#       copying sknetwork\hierarchy\louvain_hierarchy.py -> build\lib.win-amd64-cpython-311\sknetwork\hierarchy
#       copying sknetwork\hierarchy\metrics.py -> build\lib.win-amd64-cpython-311\sknetwork\hierarchy
#       copying sknetwork\hierarchy\postprocess.py -> build\lib.win-amd64-cpython-311\sknetwork\hierarchy
#       copying sknetwork\hierarchy\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\hierarchy
#       creating build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\linalg\basics.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\linalg\eig_solver.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\linalg\laplacian.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\linalg\normalization.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\linalg\operators.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\linalg\polynome.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\linalg\ppr_solver.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\linalg\sparse_lowrank.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\linalg\svd_solver.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\linalg\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       creating build\lib.win-amd64-cpython-311\sknetwork\linkpred
#       copying sknetwork\linkpred\base.py -> build\lib.win-amd64-cpython-311\sknetwork\linkpred
#       copying sknetwork\linkpred\nn.py -> build\lib.win-amd64-cpython-311\sknetwork\linkpred
#       copying sknetwork\linkpred\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\linkpred
#       creating build\lib.win-amd64-cpython-311\sknetwork\path
#       copying sknetwork\path\metrics.py -> build\lib.win-amd64-cpython-311\sknetwork\path
#       copying sknetwork\path\search.py -> build\lib.win-amd64-cpython-311\sknetwork\path
#       copying sknetwork\path\shortest_path.py -> build\lib.win-amd64-cpython-311\sknetwork\path
#       copying sknetwork\path\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\path
#       creating build\lib.win-amd64-cpython-311\sknetwork\ranking
#       copying sknetwork\ranking\base.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking
#       copying sknetwork\ranking\closeness.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking
#       copying sknetwork\ranking\harmonic.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking
#       copying sknetwork\ranking\hits.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking
#       copying sknetwork\ranking\katz.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking
#       copying sknetwork\ranking\pagerank.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking
#       copying sknetwork\ranking\postprocess.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking
#       copying sknetwork\ranking\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking
#       creating build\lib.win-amd64-cpython-311\sknetwork\regression
#       copying sknetwork\regression\base.py -> build\lib.win-amd64-cpython-311\sknetwork\regression
#       copying sknetwork\regression\diffusion.py -> build\lib.win-amd64-cpython-311\sknetwork\regression
#       copying sknetwork\regression\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\regression
#       creating build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\topology\dag.py -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\topology\structure.py -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\topology\weisfeiler_lehman.py -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\topology\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       creating build\lib.win-amd64-cpython-311\sknetwork\utils
#       copying sknetwork\utils\base.py -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       copying sknetwork\utils\check.py -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       copying sknetwork\utils\format.py -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       copying sknetwork\utils\membership.py -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       copying sknetwork\utils\neighbors.py -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       copying sknetwork\utils\simplex.py -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       copying sknetwork\utils\tfidf.py -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       copying sknetwork\utils\timeout.py -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       copying sknetwork\utils\values.py -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       copying sknetwork\utils\verbose.py -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       copying sknetwork\utils\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       creating build\lib.win-amd64-cpython-311\sknetwork\visualization
#       copying sknetwork\visualization\colors.py -> build\lib.win-amd64-cpython-311\sknetwork\visualization
#       copying sknetwork\visualization\dendrograms.py -> build\lib.win-amd64-cpython-311\sknetwork\visualization
#       copying sknetwork\visualization\graphs.py -> build\lib.win-amd64-cpython-311\sknetwork\visualization
#       copying sknetwork\visualization\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\visualization
#       creating build\lib.win-amd64-cpython-311\sknetwork\classification\tests
#       copying sknetwork\classification\tests\test_API.py -> build\lib.win-amd64-cpython-311\sknetwork\classification\tests
#       copying sknetwork\classification\tests\test_diffusion.py -> build\lib.win-amd64-cpython-311\sknetwork\classification\tests
#       copying sknetwork\classification\tests\test_knn.py -> build\lib.win-amd64-cpython-311\sknetwork\classification\tests
#       copying sknetwork\classification\tests\test_metrics.py -> build\lib.win-amd64-cpython-311\sknetwork\classification\tests
#       copying sknetwork\classification\tests\test_pagerank.py -> build\lib.win-amd64-cpython-311\sknetwork\classification\tests
#       copying sknetwork\classification\tests\test_propagation.py -> build\lib.win-amd64-cpython-311\sknetwork\classification\tests
#       copying sknetwork\classification\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\classification\tests
#       creating build\lib.win-amd64-cpython-311\sknetwork\clustering\tests
#       copying sknetwork\clustering\tests\test_API.py -> build\lib.win-amd64-cpython-311\sknetwork\clustering\tests
#       copying sknetwork\clustering\tests\test_louvain.py -> build\lib.win-amd64-cpython-311\sknetwork\clustering\tests
#       copying sknetwork\clustering\tests\test_metrics.py -> build\lib.win-amd64-cpython-311\sknetwork\clustering\tests
#       copying sknetwork\clustering\tests\test_postprocess.py -> build\lib.win-amd64-cpython-311\sknetwork\clustering\tests
#       copying sknetwork\clustering\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\clustering\tests
#       creating build\lib.win-amd64-cpython-311\sknetwork\data\tests
#       copying sknetwork\data\tests\test_API.py -> build\lib.win-amd64-cpython-311\sknetwork\data\tests
#       copying sknetwork\data\tests\test_load.py -> build\lib.win-amd64-cpython-311\sknetwork\data\tests
#       copying sknetwork\data\tests\test_models.py -> build\lib.win-amd64-cpython-311\sknetwork\data\tests
#       copying sknetwork\data\tests\test_parse.py -> build\lib.win-amd64-cpython-311\sknetwork\data\tests
#       copying sknetwork\data\tests\test_test_graphs.py -> build\lib.win-amd64-cpython-311\sknetwork\data\tests
#       copying sknetwork\data\tests\test_toy_graphs.py -> build\lib.win-amd64-cpython-311\sknetwork\data\tests
#       copying sknetwork\data\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\data\tests
#       creating build\lib.win-amd64-cpython-311\sknetwork\embedding\tests
#       copying sknetwork\embedding\tests\test_API.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding\tests
#       copying sknetwork\embedding\tests\test_force_atlas.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding\tests
#       copying sknetwork\embedding\tests\test_louvain_embedding.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding\tests
#       copying sknetwork\embedding\tests\test_louvain_hierarchy.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding\tests
#       copying sknetwork\embedding\tests\test_random_projection.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding\tests
#       copying sknetwork\embedding\tests\test_spectral.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding\tests
#       copying sknetwork\embedding\tests\test_spring.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding\tests
#       copying sknetwork\embedding\tests\test_svd.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding\tests
#       copying sknetwork\embedding\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\embedding\tests
#       creating build\lib.win-amd64-cpython-311\sknetwork\gnn\tests
#       copying sknetwork\gnn\tests\test_activation.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn\tests
#       copying sknetwork\gnn\tests\test_base.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn\tests
#       copying sknetwork\gnn\tests\test_base_layer.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn\tests
#       copying sknetwork\gnn\tests\test_gnn_classifier.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn\tests
#       copying sknetwork\gnn\tests\test_layers.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn\tests
#       copying sknetwork\gnn\tests\test_loss.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn\tests
#       copying sknetwork\gnn\tests\test_neigh_sampler.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn\tests
#       copying sknetwork\gnn\tests\test_optimizer.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn\tests
#       copying sknetwork\gnn\tests\test_utils.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn\tests
#       copying sknetwork\gnn\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\gnn\tests
#       creating build\lib.win-amd64-cpython-311\sknetwork\hierarchy\tests
#       copying sknetwork\hierarchy\tests\test_algos.py -> build\lib.win-amd64-cpython-311\sknetwork\hierarchy\tests
#       copying sknetwork\hierarchy\tests\test_API.py -> build\lib.win-amd64-cpython-311\sknetwork\hierarchy\tests
#       copying sknetwork\hierarchy\tests\test_metrics.py -> build\lib.win-amd64-cpython-311\sknetwork\hierarchy\tests
#       copying sknetwork\hierarchy\tests\test_postprocess.py -> build\lib.win-amd64-cpython-311\sknetwork\hierarchy\tests
#       copying sknetwork\hierarchy\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\hierarchy\tests
#       creating build\lib.win-amd64-cpython-311\sknetwork\linalg\tests
#       copying sknetwork\linalg\tests\test_eig.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg\tests
#       copying sknetwork\linalg\tests\test_laplacian.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg\tests
#       copying sknetwork\linalg\tests\test_normalization.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg\tests
#       copying sknetwork\linalg\tests\test_operators.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg\tests
#       copying sknetwork\linalg\tests\test_polynome.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg\tests
#       copying sknetwork\linalg\tests\test_ppr.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg\tests
#       copying sknetwork\linalg\tests\test_sparse_lowrank.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg\tests
#       copying sknetwork\linalg\tests\test_svd.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg\tests
#       copying sknetwork\linalg\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\linalg\tests
#       creating build\lib.win-amd64-cpython-311\sknetwork\linkpred\tests
#       copying sknetwork\linkpred\tests\test_nn.py -> build\lib.win-amd64-cpython-311\sknetwork\linkpred\tests
#       copying sknetwork\linkpred\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\linkpred\tests
#       creating build\lib.win-amd64-cpython-311\sknetwork\path\tests
#       copying sknetwork\path\tests\test_metrics.py -> build\lib.win-amd64-cpython-311\sknetwork\path\tests
#       copying sknetwork\path\tests\test_search.py -> build\lib.win-amd64-cpython-311\sknetwork\path\tests
#       copying sknetwork\path\tests\test_shortest_path.py -> build\lib.win-amd64-cpython-311\sknetwork\path\tests
#       copying sknetwork\path\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\path\tests
#       creating build\lib.win-amd64-cpython-311\sknetwork\ranking\tests
#       copying sknetwork\ranking\tests\test_API.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking\tests
#       copying sknetwork\ranking\tests\test_betweenness.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking\tests
#       copying sknetwork\ranking\tests\test_closeness.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking\tests
#       copying sknetwork\ranking\tests\test_hits.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking\tests
#       copying sknetwork\ranking\tests\test_pagerank.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking\tests
#       copying sknetwork\ranking\tests\test_postprocess.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking\tests
#       copying sknetwork\ranking\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\ranking\tests
#       creating build\lib.win-amd64-cpython-311\sknetwork\regression\tests
#       copying sknetwork\regression\tests\test_API.py -> build\lib.win-amd64-cpython-311\sknetwork\regression\tests
#       copying sknetwork\regression\tests\test_diffusion.py -> build\lib.win-amd64-cpython-311\sknetwork\regression\tests
#       copying sknetwork\regression\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\regression\tests
#       creating build\lib.win-amd64-cpython-311\sknetwork\topology\tests
#       copying sknetwork\topology\tests\test_cliques.py -> build\lib.win-amd64-cpython-311\sknetwork\topology\tests
#       copying sknetwork\topology\tests\test_cores.py -> build\lib.win-amd64-cpython-311\sknetwork\topology\tests
#       copying sknetwork\topology\tests\test_dag.py -> build\lib.win-amd64-cpython-311\sknetwork\topology\tests
#       copying sknetwork\topology\tests\test_structure.py -> build\lib.win-amd64-cpython-311\sknetwork\topology\tests
#       copying sknetwork\topology\tests\test_triangles.py -> build\lib.win-amd64-cpython-311\sknetwork\topology\tests
#       copying sknetwork\topology\tests\test_wl_coloring.py -> build\lib.win-amd64-cpython-311\sknetwork\topology\tests
#       copying sknetwork\topology\tests\test_wl_kernel.py -> build\lib.win-amd64-cpython-311\sknetwork\topology\tests
#       copying sknetwork\topology\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\topology\tests
#       creating build\lib.win-amd64-cpython-311\sknetwork\utils\tests
#       copying sknetwork\utils\tests\test_base.py -> build\lib.win-amd64-cpython-311\sknetwork\utils\tests
#       copying sknetwork\utils\tests\test_bunch.py -> build\lib.win-amd64-cpython-311\sknetwork\utils\tests
#       copying sknetwork\utils\tests\test_check.py -> build\lib.win-amd64-cpython-311\sknetwork\utils\tests
#       copying sknetwork\utils\tests\test_format.py -> build\lib.win-amd64-cpython-311\sknetwork\utils\tests
#       copying sknetwork\utils\tests\test_membership.py -> build\lib.win-amd64-cpython-311\sknetwork\utils\tests
#       copying sknetwork\utils\tests\test_neighbors.py -> build\lib.win-amd64-cpython-311\sknetwork\utils\tests
#       copying sknetwork\utils\tests\test_projection_simplex.py -> build\lib.win-amd64-cpython-311\sknetwork\utils\tests
#       copying sknetwork\utils\tests\test_tfidf.py -> build\lib.win-amd64-cpython-311\sknetwork\utils\tests
#       copying sknetwork\utils\tests\test_values.py -> build\lib.win-amd64-cpython-311\sknetwork\utils\tests
#       copying sknetwork\utils\tests\test_verbose.py -> build\lib.win-amd64-cpython-311\sknetwork\utils\tests
#       copying sknetwork\utils\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\utils\tests
#       creating build\lib.win-amd64-cpython-311\sknetwork\visualization\tests
#       copying sknetwork\visualization\tests\test_dendrograms.py -> build\lib.win-amd64-cpython-311\sknetwork\visualization\tests
#       copying sknetwork\visualization\tests\test_graphs.py -> build\lib.win-amd64-cpython-311\sknetwork\visualization\tests
#       copying sknetwork\visualization\tests\__init__.py -> build\lib.win-amd64-cpython-311\sknetwork\visualization\tests
#       running egg_info
#       writing scikit_network.egg-info\PKG-INFO
#       writing dependency_links to scikit_network.egg-info\dependency_links.txt
#       writing requirements to scikit_network.egg-info\requires.txt
#       writing top-level names to scikit_network.egg-info\top_level.txt
#       reading manifest file 'scikit_network.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching '*' under directory 'tests'
#       warning: no previously-included files matching '__pycache__' found under directory '*'
#       warning: no previously-included files matching '*.py[co]' found under directory '*'
#       warning: no files found matching '*.jpg' under directory 'docs'
#       warning: no files found matching '*.png' under directory 'docs'
#       warning: no files found matching '*.gif' under directory 'docs'
#       adding license file 'LICENSE'
#       adding license file 'AUTHORS.rst'
#       writing manifest file 'scikit_network.egg-info\SOURCES.txt'
#       copying sknetwork\classification\vote.cpp -> build\lib.win-amd64-cpython-311\sknetwork\classification
#       copying sknetwork\classification\vote.pyx -> build\lib.win-amd64-cpython-311\sknetwork\classification
#       copying sknetwork\clustering\louvain_core.cpp -> build\lib.win-amd64-cpython-311\sknetwork\clustering
#       copying sknetwork\clustering\louvain_core.pyx -> build\lib.win-amd64-cpython-311\sknetwork\clustering
#       copying sknetwork\hierarchy\paris.cpp -> build\lib.win-amd64-cpython-311\sknetwork\hierarchy
#       copying sknetwork\hierarchy\paris.pyx -> build\lib.win-amd64-cpython-311\sknetwork\hierarchy
#       copying sknetwork\linalg\diteration.cpp -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\linalg\diteration.pyx -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\linalg\push.cpp -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\linalg\push.pyx -> build\lib.win-amd64-cpython-311\sknetwork\linalg
#       copying sknetwork\ranking\betweenness.cpp -> build\lib.win-amd64-cpython-311\sknetwork\ranking
#       copying sknetwork\ranking\betweenness.pyx -> build\lib.win-amd64-cpython-311\sknetwork\ranking
#       copying sknetwork\topology\dag_core.cpp -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\topology\dag_core.pyx -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\topology\kcliques.cpp -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\topology\kcliques.pyx -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\topology\kcore.cpp -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\topology\kcore.pyx -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\topology\triangles.cpp -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\topology\triangles.pyx -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\topology\weisfeiler_lehman_core.cpp -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\topology\weisfeiler_lehman_core.pyx -> build\lib.win-amd64-cpython-311\sknetwork\topology
#       copying sknetwork\utils\minheap.cpp -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       copying sknetwork\utils\minheap.pxd -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       copying sknetwork\utils\minheap.pyx -> build\lib.win-amd64-cpython-311\sknetwork\utils
#       running build_ext
#       building 'sknetwork.classification.vote' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for scikit-network
# ERROR: Could not build wheels for scikit-network, which is required to install pyproject.toml-based projects

# %% [markdown]
# ## Import

# %%
from IPython.display import SVG

# %%
from sknetwork.data import karate_club, load_netset
from sknetwork.visualization import svg_graph

# %% [markdown]
# ## Check

# %%
graph = karate_club(metadata=True)
adjacency = graph.adjacency
position = graph.position
labels = graph.labels

# %%
image = svg_graph(adjacency, position, labels=labels)

# %%
SVG(image)

# %%
dataset = load_netset('openflights')

# %%
dataset

# %%
len(dataset.names) == 3097
